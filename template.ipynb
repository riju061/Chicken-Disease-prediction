# %%
import os
if 'PYTHONHOME' in os.environ:
   del os.environ['PYTHONHOME']




import os
from pathlib import Path
import logging

logging.basicConfig(level=logging.INFO, format='[%(asctime)s]: %(message)s:')


project_name = "cnnClassifier"

list_of_files = [
    ".github/workflows/.gitkeep",
    f"src/{project_name}/__init__.py",
    f"src/{project_name}/components/__init__.py",
    f"src/{project_name}/utils/__init__.py",
    f"src/{project_name}/config/__init__.py",
    f"src/{project_name}/config/configuration.py",
    f"src/{project_name}/pipeline/__init__.py",
    f"src/{project_name}/entity/__init__.py",
    f"src/{project_name}/constants/__init__.py",
    "config/config.yaml",
    "dvc.yaml",
    "params.yaml",
    "requirements.txt",
    "setup.py",
    "research/trials.ipynb",
    "templates/index.html"


]


for filepath in list_of_files:
    filepath = Path(filepath)
    filedir, filename = os.path.split(filepath)


    if filedir !="":
        os.makedirs(filedir, exist_ok=True)
        logging.info(f"Creating directory; {filedir} for the file: {filename}")

    if (not os.path.exists(filepath)) or (os.path.getsize(filepath) == 0):
        with open(filepath, "w") as f:
            pass
            logging.info(f"Creating empty file: {filepath}")



    else:
        logging.info(f"{filename} is already exists")
# Out:
# [2023-06-24 00:32:39,767]: Creating directory; .github\workflows for the file: .gitkeep:
# [2023-06-24 00:32:39,771]: Creating empty file: .github\workflows\.gitkeep:
# [2023-06-24 00:32:39,773]: Creating directory; src\cnnClassifier for the file: __init__.py:
# [2023-06-24 00:32:39,775]: Creating empty file: src\cnnClassifier\__init__.py:
# [2023-06-24 00:32:39,777]: Creating directory; src\cnnClassifier\components for the file: __init__.py:
# [2023-06-24 00:32:39,778]: Creating empty file: src\cnnClassifier\components\__init__.py:
# [2023-06-24 00:32:39,780]: Creating directory; src\cnnClassifier\utils for the file: __init__.py:
# [2023-06-24 00:32:39,782]: Creating empty file: src\cnnClassifier\utils\__init__.py:
# [2023-06-24 00:32:39,784]: Creating directory; src\cnnClassifier\config for the file: __init__.py:
# [2023-06-24 00:32:39,786]: Creating empty file: src\cnnClassifier\config\__init__.py:
# [2023-06-24 00:32:39,790]: Creating directory; src\cnnClassifier\config for the file: configuration.py:
# [2023-06-24 00:32:39,792]: Creating empty file: src\cnnClassifier\config\configuration.py:
# [2023-06-24 00:32:39,801]: Creating directory; src\cnnClassifier\pipeline for the file: __init__.py:
# [2023-06-24 00:32:39,803]: Creating empty file: src\cnnClassifier\pipeline\__init__.py:
# [2023-06-24 00:32:39,805]: Creating directory; src\cnnClassifier\entity for the file: __init__.py:
# [2023-06-24 00:32:39,807]: Creating empty file: src\cnnClassifier\entity\__init__.py:
# [2023-06-24 00:32:39,810]: Creating directory; src\cnnClassifier\constants for the file: __init__.py:
# [2023-06-24 00:32:39,813]: Creating empty file: src\cnnClassifier\constants\__init__.py:
# [2023-06-24 00:32:39,817]: Creating directory; config for the file: config.yaml:
# [2023-06-24 00:32:39,819]: Creating empty file: config\config.yaml:
# [2023-06-24 00:32:39,821]: Creating empty file: dvc.yaml:
# [2023-06-24 00:32:39,823]: Creating empty file: params.yaml:
# [2023-06-24 00:32:39,826]: Creating empty file: requirements.txt:
# [2023-06-24 00:32:39,828]: Creating empty file: setup.py:
# [2023-06-24 00:32:39,830]: Creating directory; research for the file: trials.ipynb:
# [2023-06-24 00:32:39,834]: Creating empty file: research\trials.ipynb:
# [2023-06-24 00:32:39,837]: Creating directory; templates for the file: index.html:
# [2023-06-24 00:32:39,839]: Creating empty file: templates\index.html:
